# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import random
from tensorflow.keras.models import load_model
from pathlib import Path

DATASET_PATH = Path("../MultiLabelFrames")
CSV_PATH = DATASET_PATH / "labels_filtered.csv"
MODEL_PATH = ("../mentett_model/traffic_sign_model.h5")
IMG_SIZE = (256, 256)
THRESHOLD = 0.5
NUM_SAMPLES = 10

model = load_model(MODEL_PATH)
df = pd.read_csv(CSV_PATH)
sign_names = df.columns.drop("filename").tolist()

# Véletlenszerű képek kiválasztása
samples = df.sample(NUM_SAMPLES, random_state=42)

def load_image(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.expand_dims(image / 255.0, axis=0)
    return image

# Előrejelzés és kiírás
for _, row in samples.iterrows():
    image_path = str(DATASET_PATH / row["filename"])
    label_vector = row.drop("filename").values.astype("float32")
    true_labels = [sign for sign, val in zip(sign_names, label_vector) if val == 1]

    image = load_image(image_path)
    prediction = model.predict(image)[0]
    predicted_labels = [sign for sign, val in zip(sign_names, prediction) if val > THRESHOLD]

    print(f"📷 {row['filename']}")
    print(f"✅ Valós címkék   : {true_labels}")
    print(f"🤖 Modell jóslata : {predicted_labels}")
    print("-" * 60)
# Out:
# 1/1 [==============================] - 6s 6s/step
# 📷 0117_25.5_766.jpg
# ✅ Valós címkék   : ['parkolo']
# 🤖 Modell jóslata : ['parkolo']
# ------------------------------------------------------------
# 1/1 [==============================] - 0s 39ms/step
# 📷 0013_0.0_-1.jpg
# ✅ Valós címkék   : ['behajtaniTilosMegjeloltDolgokkal']
# 🤖 Modell jóslata : ['behajtaniTilosMegjeloltDolgokkal']
# ------------------------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# 📷 0010_18.5_548.jpg
# ✅ Valós címkék   : ['buszmegallo']
# 🤖 Modell jóslata : ['buszmegallo']
# ------------------------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# 📷 0180_24.5_735.jpg
# ✅ Valós címkék   : ['50']
# 🤖 Modell jóslata : ['50']
# ------------------------------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# 📷 0164_21.0_631.jpg
# ✅ Valós címkék   : ['foutvonal', 'gyerekek']
# 🤖 Modell jóslata : ['foutvonal', 'gyerekek']
# ------------------------------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# 📷 0040_24.0_710.jpg
# ✅ Valós címkék   : ['elsobbsegadas']
# 🤖 Modell jóslata : ['elsobbsegadas']
# ------------------------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# 📷 0214_18.5_556.jpg
# ✅ Valós címkék   : ['70', 'varakozniTilos']
# 🤖 Modell jóslata : ['70', 'varakozniTilos']
# ------------------------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# 📷 0204_2.0_61.jpg
# ✅ Valós címkék   : ['foutvonal', 'varakozniTilos']
# 🤖 Modell jóslata : ['foutvonal', 'varakozniTilos']
# ------------------------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# 📷 0121_2.5_76.jpg
# ✅ Valós címkék   : ['foutvonal']
# 🤖 Modell jóslata : ['foutvonal']
# ------------------------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# 📷 0117_28.0_839.jpg
# ✅ Valós címkék   : ['foutvonal']
# 🤖 Modell jóslata : ['foutvonal']
# ------------------------------------------------------------
